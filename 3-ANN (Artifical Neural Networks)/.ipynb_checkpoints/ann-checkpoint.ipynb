# %% [markdown]
# # ARTIFICAL NERURAL NERTWORK

# %% [markdown]
# ARTIFICAL NERURAL NERTWORK NEDİR?
#
# Deep learning ile aynı şeydir. Logistic regresyonun en az iki kere tekrar edilmesiyle oluşan katmanlı mimaridir. input ve output layerin arasında en az bir tane hidden layer yani gizlenmiş bir layerin olduğu durumlardır.
#
# Deep hidden layerin sayısıdır. Ne kadar hidden layer varsa o kadar deep olur.
#
# Peki neden hidden? hidden layerlar bizim inputlarımızın ne olduğunu göremezler.

# %% [markdown]
# Input ve output layerin arasında bir veya birden fazla hidden layer bulunabilir. Input sayısı kaç ise o kadar node bulunur. Çıkış ise bir node' dan oluşur. Hidden layer içindeki node sayısını, learning rate ve hidden layer sayısını elle seçeriz. Bunlar bizim hyper parametrelerimiz. Aslıda modelin başarısını belirleyecek ve ilerleyen dönemlerde güncelleyerek en iy isonuca ulaşmayı hedeflediğimiz bölüm budur.
#
#
# Adımlarımız şu şekilde input nodelarımızı bir weight değeri ile çarpıp ardınan bir bias değeri ile topluyoruz. (Logistic regresyonun aynısı) ardından elde ettiğimiz değer Z değeri oluyor. Bu Z değerini "tanh" fonksiyonuna sokuyoruz. Logistic regresyondaki sigmoid fonksiyonu gibi activation fonksiyonudur. Sigmoidden farkı nedir?
#
#
# Sigmoid prbablistic bir değer ortaya koyar (0,1) arasındadır. tanh (1,-1) arasında sıkıştırır. tanh fonksiyonun hidden layer^da kullanımı daha kârlı oluyor. Değer ortalamaları 0'a daha yakın olmasıdır. Bu benim datamı daha iyi merkezde tuttuğum anlamına gelir. Ardından hidden layera geldik. İşte bu bizim gördüğümüz ilk an. Yine buradaki hidden layerin nodelarını orada geçerli olan wweightlerle çarpıktan ve bias ile topladıktan sonra Z_2 değerini sigmoid fonksiyona sokup ardından y_head değerimizi elde etmiş oluyoruz.
#
#
# Burada activation methodlarının kullanımla sebebi bizim  datamızdan öğrendiğimiz modeldeki non-linear özelliğini arttırmak. Non- Linearlik özelliği ne kadar karmaşıklarsa datayı o kadar iyi öğrenirim anlamına gelir.
#
# Logistic regresyondaki ana fark activation fonksiyonumuzun tanh oluyor olmasıdır.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # 2-LAYER NEURAL NETWORKS

# %% [markdown]
# BU ADIMDA YAPILACAKLAR:
#
#     Size of layers and initializing parameters weights and bias
#
#     Forward Propagation
#
#     Loss Function and Cost Function
#
#     Bacward Propagation
#
#     Update Parameters
#
#     Prediction with learnt parameters weight and bias
#
#     Create Model

# %% [markdown]
#     Size of layers and initializing parameters weights and bias

# %% [markdown]
# Güncellenmemiz gereken (iki layer için) w1,w2,b1 ve b2 değerleri sayarsak 4 değer var. Bias için 0 değeriyle başlarken weight için 0.01 değeriyle initialize edeceğiz. Bu sefer random bir şekilde initalize yapacağız.

# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt

"""
Algoritmalara güncelleme geldiği zaman, eski modu kullandığımıza dair uyarılar verilebiliyor. Bu uyarıları görmemek için 
aşağıdaki kodu yazarız:
"""

# import warnings
import warnings
# filter warnings
warnings.filterwarnings('ignore')

# %%
x_l = np.load('X.npy')
Y_l = np.load('Y.npy')
img_size = 64
plt.subplot(1, 2, 1)
plt.imshow(x_l[260].reshape(img_size, img_size))
plt.axis('off')
plt.subplot(1, 2, 2)
plt.imshow(x_l[900].reshape(img_size, img_size))
plt.axis('off')
# Out:
# (-0.5, 63.5, 63.5, -0.5)

# %%
X = np.concatenate((x_l[204:409], x_l[822:1027] ), axis=0) # from 0 to 204 is zero sign and from 205 to 410 is one sign 
z = np.zeros(205)
o = np.ones(205)
Y = np.concatenate((z, o), axis=0).reshape(X.shape[0],1)
print("X shape: " , X.shape)
print("Y shape: " , Y.shape)
# Out:
# X shape:  (410, 64, 64)
# Y shape:  (410, 1)

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.15, random_state=42)
number_of_train = X_train.shape[0] #train sample sayısı number_of_train değişkenine atanmıştır.
number_of_test = X_test.shape[0]   #test sample sayısı number_of_test değişkenine atanmıştır.

# %%
X_train_flatten = X_train.reshape(number_of_train,X_train.shape[1]*X_train.shape[2])
X_test_flatten = X_test .reshape(number_of_test,X_test.shape[1]*X_test.shape[2])
print("X train flatten",X_train_flatten.shape)
print("X test flatten",X_test_flatten.shape)
# Out:
# X train flatten (348, 4096)
# X test flatten (62, 4096)

# %%
x_train = X_train_flatten.T
x_test = X_test_flatten.T
y_train = Y_train.T
y_test = Y_test.T
print("x train: ",x_train.shape)
print("x test: ",x_test.shape)
print("y train: ",y_train.shape)
print("y test: ",y_test.shape)
# Out:
# x train:  (4096, 348)
# x test:  (4096, 62)
# y train:  (1, 348)
# y test:  (1, 62)

# %% [markdown]
# Hidden layer'da üç tane olduğunu varsayarak, normalde 1,4096 olmasına rağmen 3,4096 olarak varsayıyoruz. Ve ona göre bir weight1 değişkeni oluşturduk.

# %%
# intialize parameters and layer sizes
def initialize_parameters_and_layer_sizes_NN(x_train, y_train):
    parameters = {"weight1": np.random.randn(3,x_train.shape[0]) * 0.1,
                  "bias1": np.zeros((3 ,1)),
                  "weight2": np.random.randn(y_train.shape[0],3) * 0.1,
                  "bias2": np.zeros((y_train.shape[0],1))}
    return parameters

# %% [markdown]
# # FORWARD PROPAGATION

# %% [markdown]
# Forward propagation tamaıyla logistic regresyonla aynıdır.
# Öncesinde girdi değişkenlerini weight1 ile çarpıp ardından +bias1 ve sonrasında tanh fonksiyonuna sokuyoruz. Ardından hidden layer'a giriyoruz. Bizim örneğimizde hidden layer 3 node'dan oluşur gibi düşündük ve ardından weight2 değerleriyle çarpıp ardıdan bias2 ile topluyoruz. Ve çıkış Z2 yi sigmoid fonksiyonuna sokuyoruz. Ardından bir çıkış elde ediyoruz. Kodlayalım!!!

# %%
def forward_propagation_NN(x_train, parameters):

    Z1 = np.dot(parameters["weight1"],x_train) +parameters["bias1"]
    A1 = np.tanh(Z1)
    Z2 = np.dot(parameters["weight2"],A1) + parameters["bias2"]
    A2 = sigmoid(Z2)

    cache = {"Z1": Z1,
             "A1": A1,
             "Z2": Z2,
             "A2": A2}
    
    return A2, cache

# %% [markdown]
# # LOSS AND COST FUNCTION

# %%
# Compute cost
def compute_cost_NN(A2, Y, parameters):
    logprobs = np.multiply(np.log(A2),Y)
    cost = -np.sum(logprobs)/Y.shape[1]
    return cost

# %% [markdown]
# # BACKWARD PROPAGATION

# %% [markdown]
# Hyperparameterlerin ayarlanma sürecinde türev alarak en optimize ayarlanmasıdır.

# %%
# Backward Propagation
def backward_propagation_NN(parameters, cache, X, Y):

    dZ2 = cache["A2"]-Y  #cost'un z2'ye göre türevidir.
    dW2 = np.dot(dZ2,cache["A1"].T)/X.shape[1]
    db2 = np.sum(dZ2,axis =1,keepdims=True)/X.shape[1]
    dZ1 = np.dot(parameters["weight2"].T,dZ2)*(1 - np.power(cache["A1"], 2))  #cost'un Z1'e göre türevi demektir.
    dW1 = np.dot(dZ1,X.T)/X.shape[1]  #cost'un w1'e göre türevi demektir.
    db1 = np.sum(dZ1,axis =1,keepdims=True)/X.shape[1]
    grads = {"dweight1": dW1,
             "dbias1": db1,
             "dweight2": dW2,
             "dbias2": db2}
    return grads

# %% [markdown]
# # UPDATE PARAMETERS

# %%
# update parameters
def update_parameters_NN(parameters, grads, learning_rate = 0.01):
    parameters = {"weight1": parameters["weight1"]-learning_rate*grads["dweight1"],
                  "bias1": parameters["bias1"]-learning_rate*grads["dbias1"],
                  "weight2": parameters["weight2"]-learning_rate*grads["dweight2"],
                  "bias2": parameters["bias2"]-learning_rate*grads["dbias2"]}
    
    return parameters

# %% [markdown]
# Parametreler update edildiği için model hazırdır dolaysıyla tahmin yapmaya hazırız.

# %% [markdown]
# # PREDICTION

# %%
# prediction
def predict_NN(parameters,x_test):
    # x_test is a input for forward propagation
    A2, cache = forward_propagation_NN(x_test,parameters)
    Y_prediction = np.zeros((1,x_test.shape[1]))
    # if z is bigger than 0.5, our prediction is sign one (y_head=1),
    # if z is smaller than 0.5, our prediction is sign zero (y_head=0),
    for i in range(A2.shape[1]):
        if A2[0,i]<= 0.5:
            Y_prediction[0,i] = 0
        else:
            Y_prediction[0,i] = 1

    return Y_prediction

# %% [markdown]
# Bu metodun temel işlevi, eğitilmiş bir model ve bir veri kümesi aldığında, modelin veri kümesindeki örnekler için sınıf tahminleri yapmasını sağlamaktır. Bu yöntem, eğitim sırasında belirlenen eşik değeri 0.5'e göre sınıflandırma yaparak, y_head değerlerini 0 veya 1 olarak atar. Bu değerleri y_prediction adlı bir numpy array'inde saklayarak, tahmin edilen sınıfları döndürür.

# %% [markdown]
# # Create ANN Model

# %%
# calculation of z
#z = np.dot(w.T,x_train)+b
def sigmoid(z):
    y_head = 1/(1+np.exp(-z))
    return y_head

# %%
# 2 - Layer neural network
def two_layer_neural_network(x_train, y_train,x_test,y_test, num_iterations):
    cost_list = []
    index_list = []
    #initialize parameters and layer sizes
    parameters = initialize_parameters_and_layer_sizes_NN(x_train, y_train)

    for i in range(0, num_iterations):
         # forward propagation
        A2, cache = forward_propagation_NN(x_train,parameters)
        # compute cost
        cost = compute_cost_NN(A2, y_train, parameters)
         # backward propagation
        grads = backward_propagation_NN(parameters, cache, x_train, y_train)
         # update parameters
        parameters = update_parameters_NN(parameters, grads)
        
        if i % 100 == 0:
            cost_list.append(cost)
            index_list.append(i)
            print ("Cost after iteration %i: %f" %(i, cost))
    plt.plot(index_list,cost_list)
    plt.xticks(index_list,rotation='vertical')
    plt.xlabel("Number of Iterarion")
    plt.ylabel("Cost")
    plt.show()
    
    # predict
    y_prediction_test = predict_NN(parameters,x_test)
    y_prediction_train = predict_NN(parameters,x_train)

    # Print train/test Errors
    print("train accuracy: {} %".format(100 - np.mean(np.abs(y_prediction_train - y_train)) * 100))
    print("test accuracy: {} %".format(100 - np.mean(np.abs(y_prediction_test - y_test)) * 100))
    return parameters

parameters = two_layer_neural_network(x_train, y_train,x_test,y_test, num_iterations=2500)
# Out:
# Cost after iteration 0: 0.365133
# Cost after iteration 100: 0.348023
# Cost after iteration 200: 0.329920
# Cost after iteration 300: 0.294839
# Cost after iteration 400: 0.253043
# Cost after iteration 500: 0.214856
# Cost after iteration 600: 0.182835
# Cost after iteration 700: 0.128169
# Cost after iteration 800: 0.134905
# Cost after iteration 900: 0.119381
# Cost after iteration 1000: 0.109182
# Cost after iteration 1100: 0.098598
# Cost after iteration 1200: 0.089486
# Cost after iteration 1300: 0.081622
# Cost after iteration 1400: 0.074766
# Cost after iteration 1500: 0.068674
# Cost after iteration 1600: 0.048113
# Cost after iteration 1700: 0.059193
# Cost after iteration 1800: 0.054705
# Cost after iteration 1900: 0.050989
# Cost after iteration 2000: 0.047872
# Cost after iteration 2100: 0.045214
# Cost after iteration 2200: 0.042914
# Cost after iteration 2300: 0.040899
# Cost after iteration 2400: 0.039118
# train accuracy: 99.71264367816092 %
# ...

# %% [markdown]
# # L Layer Neural Network

# %% [markdown]
# Hidden layer sayımı arttırırsam ne olur? Resmin detaylarını keşfeder. Burada non linearity arttırmş oluruz ve datayı daha train eder. learning rate,  hidden layer node sayısı ve iterasyon sayısı birer hyperparametredir. Değiştitmek bizim elimizdedir.

# %%
# reshaping
x_train, x_test, y_train, y_test = x_train.T, x_test.T, y_train.T, y_test.T

# %% [markdown]
# # Implementing with keras library

# %% [markdown]
# Keras kütüphanesini kullanarak istediğimiz katmanları yaratıp ardından işlemin nasıl ilerleyeceğini belirtebiliriz.
#
# Şimdi öncelikle kerastaki import ettiğimiz sınıfları tanıyalım.
#
#
# KerasClassifier: Bir sınıftır ve keras.wrappers.scikit_learn sınıfından gelir. Scikit-Learn pipelinelarında Keras modellerini kullanmak için kullanışlı bir yol sağlar. KerasClassifier tahmin edicidir. fit, predict ve score yöntemlerini kullandığımız bir sınıftır.
#
# Cross_val_score: Bu ise hyperparametrelerin en iyi şekilde tahmin edilmesi için verisetimizi n parçaladığımız da iteratif bir şekilde her parçayı deneyerek en iyi sonucu bulmamızı sağlayan bir sınıftır.
#
#
# from keras.models import Sequential: Sequential de hedefledğimiz katman inşaa ederken biribirini takip eden katmanları ve özelliklerini yazarken kullandığımız sınıf.
#
# from keras.layers import Dense: Dense mimarimizi inşa ederken kaç katman bu katmanın özellikleri acviation meyhodları gibi nitelikleri belirlerken kullandığımız sınıftır.

# %% [markdown]
# Şimdi aşağıyı satır satır açıklayalım ve kerası tanıyalım.
#
# Bu kod Yapay sinir ağı (ann) oluşturur ve modelin performansını değerlendirmek için cross-validation yöntemini kullanır.
#
# Öncelikle "buildclassifier" adlı bir bir fonksiyon tanımlar. Bu fonksiyon bir "Sequantial" nesnesini oluşturarak ANN mdoelini inşa eder. Model  katmana sahip olacak şekikde tasarlanmıştır.
#
# classifier.add(Dense(units = 8, kernel_initializer = 'uniform', activation = 'relu', input_dim = x_train.shape[1]))
#
# ilk katman girdi boyutunu tanımlar ve 8 nörona sahiptir.
#
#
# classifier.add(Dense(units = 4, kernel_initializer = 'uniform', activation = 'relu'))
#
# ikinci katman 4 nörona sahiptir ve  aktivasyon fonksiyonu olarak reluyu kullanır.
#
#  classifier.add(Dense(units = 1, kernel_initializer = 'uniform', activation = 'sigmoid'))
#
# son katmanımız  nörona sahip ve sigmod kullanır.
#
#
# classifier.compile(optimizer = 'adam', loss = 'binary_crossentropy', metrics = ['accuracy'])
#
# Son olarak modelin derlenmesini sağlayan ve yeni veriler derlenmiş modelin üzerinde tahmin yapmak için kullanılır. Optimizasyon algoritması olarak adam fonksiyonu kullanır ve kayıp fonksiyonu olarak ise "binary_crossentropy" kullanır. Ayrıca modelin performansını ölçmek için "accurracy" methodunu kullanır.
#
#
# classifier = KerasClassifier(build_fn = build_classifier, epochs = 100)
#
# oluşturduğumuz classifier çağırıldı ardından build_fn= build_classifer parametresiyle build edilen classifier çağırıldı ve ardından 100 adımda iterative edildi.
#
# accuracies = cross_val_score(estimator = classifier, X = x_train, y = y_train, cv = 3)
#
# doğruluk hesabı için cross_val_score methodu ile doğruluk hesabı yapılmıştır. cv=3 üç farklı doğruluk hesabının ortalaması ekrana yazdırılmıştır.
#
# variance = accuracies.std()
#
#
# Bu satırda accuracy değerlerinin varyansı alınmıştır.

# %%
# Evaluating the ANN
from keras.wrappers.scikit_learn import KerasClassifier
from sklearn.model_selection import cross_val_score
from keras.models import Sequential # initialize neural network library
from keras.layers import Dense # build our layers library
def build_classifier():
    classifier = Sequential() # initialize neural network
    classifier.add(Dense(units = 8, kernel_initializer = 'uniform', activation = 'relu', input_dim = x_train.shape[1]))
    classifier.add(Dense(units = 4, kernel_initializer = 'uniform', activation = 'relu'))
    classifier.add(Dense(units = 1, kernel_initializer = 'uniform', activation = 'sigmoid'))
    classifier.compile(optimizer = 'adam', loss = 'binary_crossentropy', metrics = ['accuracy'])
    return classifier
classifier = KerasClassifier(build_fn = build_classifier, epochs = 100)
accuracies = cross_val_score(estimator = classifier, X = x_train, y = y_train, cv = 3)
mean = accuracies.mean()
variance = accuracies.std()
print("Accuracy mean: "+ str(mean))
print("Accuracy variance: "+ str(variance))
# Out:
# Epoch 1/100
# 8/8 [==============================] - 2s 7ms/step - loss: 0.6931 - accuracy: 0.5172
# Epoch 2/100
# 8/8 [==============================] - 0s 8ms/step - loss: 0.6927 - accuracy: 0.5431
# Epoch 3/100
# 8/8 [==============================] - 0s 3ms/step - loss: 0.6922 - accuracy: 0.5431
# Epoch 4/100
# 8/8 [==============================] - 0s 9ms/step - loss: 0.6908 - accuracy: 0.5431
# Epoch 5/100
# 8/8 [==============================] - 0s 8ms/step - loss: 0.6889 - accuracy: 0.5431
# Epoch 6/100
# 8/8 [==============================] - 0s 3ms/step - loss: 0.6871 - accuracy: 0.5431
# Epoch 7/100
# 8/8 [==============================] - 0s 5ms/step - loss: 0.6846 - accuracy: 0.5431
# Epoch 8/100
# 8/8 [==============================] - 0s 3ms/step - loss: 0.6802 - accuracy: 0.5431
# Epoch 9/100
# 8/8 [==============================] - 0s 3ms/step - loss: 0.6746 - accuracy: 0.5431
# Epoch 10/100
# ...
